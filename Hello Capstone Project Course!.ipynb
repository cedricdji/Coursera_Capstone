# %% [markdown]
# <a href="#"><img src = "https://3d-media.pro/images/Logo-DATA-For-Developpement.png" width = 250, align = "center"></a>

# %% [markdown]
# <center><h1> Applied Data Science Capstone </h1></center>

# %% [markdown]
# <p> Hi everevebody My name is Wilfried and i am exited to share this notebook. It will be mainly used for the capstone project. So let's go </p>

# %%
# first let's import librairies
# import pandas library as pd

import pandas as pd

# import numpy as np

import numpy as np

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
